# %% [markdown]
# ## 이미지를 받아와서 클래스별로 분류하기
#
# https://www.nongsaro.go.kr/portal/ps/psv/psvr/psvre/curationDtl.ps?menuId=PS03352&srchCurationNo=1491&totalSearchYn=Y

# %%
# 한글 폰트 설치하기 (꼭! 설치가 완료되면 [런타임 다시 시작]을 누르고 다시 실행하기)
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.2

# %%
import os
import shutil
from bing_image_downloader import downloader

directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

# 초기 디렉토리 만들기
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, train_cnt):
    # 학습 및 평가 데이터셋 디렉토리 만들기
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # 학습 및 평가 데이터셋 준비하기
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
query = '딸기'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [%] Downloading Images to /content/딸기
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 40 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://img.seoul.co.kr/img/upload/2014/11/28/SSI_20141128015717.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.wadiz.kr/wwwwadiz/green001/2019/1202/20191202142044423_53352.jpg/wadiz/format/jpg/quality/80/optimize
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.wadiz.kr/wwwwadiz/green001/2019/1129/20191129153031141_53352.jpg/wadiz/format/jpg/quality/80/optimize
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://myvenus.co.kr/files/attach/images/2040/598/475/ed50a981e75e9434d5bc3dda56594e40.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://cfile6.uf.tistory.com/image/225A834A56E2DCC7291182
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F21444D3D5799776612
# [!] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F21444D3D5799776612
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #6 from https://shop.biumfood.com/upload/images/20191203115026_374002.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://image14.hanatour.com/uploads/2015/07/IMG-6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://cfile238.uf.daum.net/image/025F7D3351638B4224D3A6
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://cfs13.blog.daum.net/image/21/blog/2008/01/13/15/34/4789b0e9afd48
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://newsimg.hankookilbo.com/cms/articlerelease/2019/11/26/201911261576072053_2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://t1.daumcdn.net/cfile/tistory/264E96495721876522
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://mn.kbs.co.kr/data/news/2018/04/05/3629681_200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 40 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #37 from http://image.chosun.com/sitedata/image/201901/08/2019010800783_0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F170FD1054C246CA982
# [!] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F170FD1054C246CA982
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #38 from https://img.insight.co.kr/static/2018/07/30/1200/mk208m6y22a64oh2kxzs.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 40 Images on Page 4.
#
# ===============================================
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 40 Images on Page 5.
#
# ===============================================
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 40 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #39 from https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FbtIY9v%2FbtqCsG5iH0e%2Fkrj0GbtgShtklqki4nCztk%2Fimg.jpg
# [!] Issue getting: https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FbtIY9v%2FbtqCsG5iH0e%2Fkrj0GbtgShtklqki4nCztk%2Fimg.jpg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 40 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #39 from http://health.chosun.com/site/data/img_dir/2014/02/26/2014022601900_0.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 40 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #40 from https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2724F43A55029D0E2B
# [!] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2724F43A55029D0E2B
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 40 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #40 from https://file.mk.co.kr/meet/neds/2021/01/image_readtop_2021_90362_16117741824520956.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 40 images.
# [Train Dataset] Image_2.jpg
# [Train Dataset] Image_33.jpg
# [Train Dataset] Image_17.jpg
# [Train Dataset] Image_36.jpg
# [Train Dataset] Image_3.jpg
# [Train Dataset] Image_27.jpg
# [Train Dataset] Image_6.jpg
# [Train Dataset] Image_37.jpg
# [Train Dataset] Image_39.jpg
# [Train Dataset] Image_25.jpg
# [Train Dataset] Image_8.jpg
# [Train Dataset] Image_1.jpg
# [Train Dataset] Image_14.jpg
# [Train Dataset] Image_21.jpg
# [Train Dataset] Image_24.jpg
# [Train Dataset] Image_16.jpg
# [Train Dataset] Image_20.jpg
# [Train Dataset] Image_15.jpg
# [Train Dataset] Image_32.jpg
# [Train Dataset] Image_10.jpg
# [Train Dataset] Image_7.jpg
# [Train Dataset] Image_13.jpg
# [Train Dataset] Image_5.jpg
# [Train Dataset] Image_29.jpg
# [Train Dataset] Image_11.jpg
# [Train Dataset] Image_4.JPG
# [Train Dataset] Image_35.jpg
# [Train Dataset] Image_40.jpg
# [Train Dataset] Image_38.jpg
# [Train Dataset] Image_28.jpg
# [Test Dataset] Image_26.jpg
# [Test Dataset] Image_12.jpg
# [Test Dataset] Image_31.jpg
# [Test Dataset] Image_18.jpg
# [Test Dataset] Image_30.jpg
# [Test Dataset] Image_34.jpg
# [Test Dataset] Image_9.jpg
# [Test Dataset] Image_19.jpg
# [Test Dataset] Image_23.jpg
# [Test Dataset] Image_22.png

# %%
query = '사과'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [%] Downloading Images to /content/사과
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 40 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://t1.daumcdn.net/cfile/tistory/25399D4F575F532F2D
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://momsmagazine.co.kr/worp/wp-content/uploads/2019/03/tip004t118845-696x464.jpg
# [Error]Invalid image, not saving http://momsmagazine.co.kr/worp/wp-content/uploads/2019/03/tip004t118845-696x464.jpg
#
# [!] Issue getting: http://momsmagazine.co.kr/worp/wp-content/uploads/2019/03/tip004t118845-696x464.jpg
# [!] Error:: Invalid image, not saving http://momsmagazine.co.kr/worp/wp-content/uploads/2019/03/tip004t118845-696x464.jpg
#
# [%] Downloading Image #2 from http://shop.biumfood.com/upload/1535360125_5131861.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.1store.io/officialProductImage/1569899583187-686277116013926.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://blogthumb2.naver.net/20090702_4/yyssccv_12465366974905wbnm_jpg/dsc_0210_chuckclose_yyssccv.jpg?type=w2
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://shop.biumfood.com/upload/1535360125_5132577.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://file.mk.co.kr/meet/neds/2015/04/image_readtop_2015_312234_14279358191849603.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://t1.daumcdn.net/cfile/tistory/99ED3F3359C51C481E
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://img.hani.co.kr/imgdb/resize/2018/1006/153873151490_20181006.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://cdn.wadiz.kr/ft/images/green001/2019/0614/20190614161937557_81.jpg/wadiz/format/jpg/quality/80/optimize
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://img.etoday.co.kr/pto_db/2015/09/20150923050934_718519_550_368.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://cfile239.uf.daum.net/image/995B36335A12B2990D6C4F
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://cfile206.uf.daum.net/image/221C6647561CD5E117ACE3
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://www.thinkfood.co.kr/news/photo/201912/86020_110960_4829.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://t1.daumcdn.net/cfile/tistory/9996B7455A5243B50F
# [%] File Downloaded !
#
# [%] Downloading Image #15 from http://cfile226.uf.daum.net/image/247DB1475867167132FE7C
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://cfile206.uf.daum.net/image/2764F83A527C914F05BFC3
# [%] File Downloaded !
#
# [%] Downloading Image #17 from http://cfile3.uf.tistory.com/image/224E253E57CD8A1B06DDEA
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F12173A3E4EE76EC101
# [!] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F12173A3E4EE76EC101
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #18 from https://contents.sixshop.com/uploadedFiles/90928/product/image_1582861991531.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://file2.nocutnews.co.kr/nocut/news/meta/20180808170441.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://t1.daumcdn.net/thumb/R1280x0/?fname=http://t1.daumcdn.net/brunch/service/user/2vLY/image/XNDn8k0q6NW4OFk8kS1I_E52TgQ.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from http://img1.daumcdn.net/thumb/R720x0/?fname=https:%2F%2Ft1.daumcdn.net%2Fliveboard%2FSNUH%2F848fc02ec863409397a3c44bdb9007cf.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://t1.daumcdn.net/cfile/tistory/9904CF355ADDCDB416
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://t1.daumcdn.net/cfile/tistory/210CD54057AC2A0B2E
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://cfile229.uf.daum.net/image/2344854155F33935258263
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://www.phillyaptrentals.com/wp-content/uploads/2016/10/apple-picking.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://cfile231.uf.daum.net/image/99B59F3B5B94C0A6100124
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://cdn.cashfeed.co.kr/attachments/c3839be593.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://vignette.wikia.nocookie.net/nutri/images/b/b3/각종_사과_종류.png/revision/latest?cb=20170502144553&amp;path-prefix=ko
# [!] Issue getting: https://vignette.wikia.nocookie.net/nutri/images/b/b3/각종_사과_종류.png/revision/latest?cb=20170502144553&amp;path-prefix=ko
# [!] Error:: 'ascii' codec can't encode characters in position 23-24: ordinal not in range(128)
# [%] Downloading Image #28 from https://news.imaeil.com/inc/photos/2019/04/29/2019042912563612755_l.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://preview.free3d.com/img-dev/2014/01/1721282628025320793/6cjl54wi-900.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://recipe1.ezmember.co.kr/cache/recipe/2019/10/01/e053e5ec6b4ed48b4601592f23956ec01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://t1.daumcdn.net/cfile/tistory/214DAD3852E864082E
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://blog.kakaocdn.net/dn/YZiGz/btqxdqHsg3G/TmrEpyujNbbtNtOsiFpkik/img.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://cdn.imweb.me/upload/S201804055ac60211e0c1d/5bc81b14a4e79.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://t1.daumcdn.net/cfile/blog/26211E4C5451CF0924
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://t1.daumcdn.net/cfile/tistory/253FA23E57CD8A1915
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://www.dogdrip.com/data/file/hotdeals/15088177804567.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from http://cfile235.uf.daum.net/image/164B18104CC271E930DF74
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 40 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #38 from https://t1.daumcdn.net/cfile/blog/1558DC4850FE6ACD14
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 40 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #39 from https://yt3.ggpht.com/a/AATXAJzyITR55B_GDCNd_MP0D6BDhxxzOD-DILGcSA=s900-c-k-c0xffffffff-no-rj-mo
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 40 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #40 from https://t1.daumcdn.net/cfile/blog/2337513858355A7F03
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 40 images.
# [Train Dataset] Image_2.jpg
# [Train Dataset] Image_33.jpg
# [Train Dataset] Image_17.jpg
# [Train Dataset] Image_36.jpg
# [Train Dataset] Image_3.jpg
# [Train Dataset] Image_27.jpg
# [Train Dataset] Image_6.jpg
# [Train Dataset] Image_37.jpg
# [Train Dataset] Image_39.jpg
# [Train Dataset] Image_25.jpg
# [Train Dataset] Image_10.JPG
# [Train Dataset] Image_4.jpg
# [Train Dataset] Image_1.jpg
# [Train Dataset] Image_14.jpg
# [Train Dataset] Image_21.jpg
# [Train Dataset] Image_24.jpg
# [Train Dataset] Image_16.jpg
# [Train Dataset] Image_20.jpg
# [Train Dataset] Image_15.jpg
# [Train Dataset] Image_32.jpg
# [Train Dataset] Image_7.jpg
# [Train Dataset] Image_8.JPG
# [Train Dataset] Image_13.jpg
# [Train Dataset] Image_5.jpg
# [Train Dataset] Image_29.jpg
# [Train Dataset] Image_11.jpg
# [Train Dataset] Image_22.jpg
# [Train Dataset] Image_35.jpg
# [Train Dataset] Image_40.jpg
# [Train Dataset] Image_38.jpg
# [Test Dataset] Image_28.jpg
# [Test Dataset] Image_26.jpg
# [Test Dataset] Image_12.jpg
# [Test Dataset] Image_31.jpg
# [Test Dataset] Image_18.jpg
# [Test Dataset] Image_30.jpg
# [Test Dataset] Image_34.jpg
# [Test Dataset] Image_9.jpg
# [Test Dataset] Image_19.jpg
# [Test Dataset] Image_23.jpg

# %%
query = 'korean pear'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [%] Downloading Images to /content/korean pear
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 40 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://cdn.tridge.com/attachment/73a535da105fcd21486bc884f2cc4ad8dddb5200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.maangchi.com/wp-content/uploads/2010/04/pear1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.gardeningknowhow.com/wp-content/uploads/2019/03/asian-pears.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cookingontheweekends.com/wp-content/uploads/2012/11/November-3-Korean-Pears4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://activerain.com/image_store/uploads/7/4/9/6/8/ar13240056086947.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://images.eatthismuch.com/site_media/img/139579_Lorgalis_75e3f133-4e3d-4365-8d4a-51b99ee12d49.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.thespruceeats.com/thmb/BR0SNntHyo2x_iWjiWEaftjMGaQ=/2093x1433/filters:fill(auto,1)/GettyImages-187510258-29d0476a9dfb4c37b6065cbee243e0f6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://4.bp.blogspot.com/-Hv86GfzBJCc/TVn45lPex0I/AAAAAAAAJec/MmrM0HY9s_g/s1600/9a+Korean+pear.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://growingfruit-images.s3-us-west-2.amazonaws.com/original/2X/0/01713017e6cf03461126166805095d0e8359180b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://i0.wp.com/momobud.sg/wp-content/uploads/2017/09/Korean-Cheong-An-Singo-Pear.jpg?zoom=3&amp;resize=250%2C250&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://cdn.shopify.com/s/files/1/0022/0774/4115/products/image_7f94b3d7-92ec-4f1a-9e1b-468b7d5dce26_1200x1200.jpg?v=1531016513
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://www.shockinglydelicious.com/wp-content/uploads/2012/11/Korean-Pears-in-a-box.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://cdn.shopify.com/s/files/1/0079/1972/products/shinko-1-lr-sq_530x@2x.jpg?v=1410464492
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://img1.southernliving.timeinc.net/sites/default/files/styles/medium_2x/public/image/2016/03/main/2256701_homeg_019.jpg?itok=NBwUIw8z
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https
jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from http://www.specialtyproduce.com/sppics/8607.png
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://farm4.staticflickr.com/3199/2905966324_e2c9ce2561_o.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 40 images.
# [Train Dataset] Image_2.jpg
# [Train Dataset] Image_33.jpg
# [Train Dataset] Image_17.jpg
# [Train Dataset] Image_36.jpg
# [Train Dataset] Image_3.jpg
# [Train Dataset] Image_27.jpg
# [Train Dataset] Image_6.jpg
# [Train Dataset] Image_25.jpg
# [Train Dataset] Image_39.png
# [Train Dataset] Image_4.jpg
# [Train Dataset] Image_1.jpg
# [Train Dataset] Image_14.jpg
# [Train Dataset] Image_21.jpg
# [Train Dataset] Image_24.jpg
# [Train Dataset] Image_16.jpg
# [Train Dataset] Image_15.jpg
# [Train Dataset] Image_32.jpg
# [Train Dataset] Image_10.jpg
# [Train Dataset] Image_20.jpeg
# [Train Dataset] Image_7.jpg
# [Train Dataset] Image_8.JPG
# [Train Dataset] Image_13.jpg
# [Train Dataset] Image_5.jpg
# [Train Dataset] Image_29.jpg
# [Train Dataset] Image_11.jpg
# [Train Dataset] Image_22.jpg
# [Train Dataset] Image_35.jpg
# [Train Dataset] Image_40.jpg
# [Train Dataset] Image_38.jpg
# [Train Dataset] Image_28.jpg
# [Test Dataset] Image_26.jpg
# [Test Dataset] Image_12.jpg
# [Test Dataset] Image_31.jpg
# [Test Dataset] Image_18.jpg
# [Test Dataset] Image_30.jpg
# [Test Dataset] Image_37.png
# [Test Dataset] Image_34.jpg
# [Test Dataset] Image_9.jpg
# [Test Dataset] Image_19.jpg
# [Test Dataset] Image_23.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# 데이터셋을 불러올 때 사용할 변형(transformation) 객체 정의
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './custom_dataset'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('학습 데이터셋 크기:', len(train_datasets))
print('테스트 데이터셋 크기:', len(test_datasets))

class_names = train_datasets.classes
print('클래스:', class_names)
# Out:
# 학습 데이터셋 크기: 90
# 테스트 데이터셋 크기: 30
# 클래스: ['korean pear', '딸기', '사과']
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0))
    # 이미지 정규화 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.imshow(input)
    plt.title(title)
    plt.show()


# 학습 데이터를 배치 단위로 불러오기
iterator = iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
num_epochs = 10
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.
    
    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))

# %%
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [예측 결과: korean pear] (실제 정답: korean pear)
# [예측 결과: 딸기] (실제 정답: 딸기)
# [예측 결과: 딸기] (실제 정답: 딸기)
# [예측 결과: korean pear] (실제 정답: korean pear)
# [예측 결과: 사과] (실제 정답: 사과)
# [예측 결과: 딸기] (실제 정답: 딸기)
# [예측 결과: 사과] (실제 정답: 사과)
# [예측 결과: korean pear] (실제 정답: korean pear)
# [Test Phase] Loss: 0.1630 Acc: 93.3333% Time: 3.3538s

# %% [markdown]
# 3. 분류 모델 API 개발
# - 학습된 분류 모델을 다른 사람이 사용할 수 있도록 API를 개발하여 배포합니다.
# - 먼저 한 장의 이미지를 파일로부터 읽어와 분류 결과를 반환하는 기능을 작성합니다.

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/4/46/Korean_pear.jpg -O test_image.jpg
# Out:
# --2022-06-28 14:29:25--  https://upload.wikimedia.org/wikipedia/commons/4/46/Korean_pear.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262749 (257K) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>] 256.59K  --.-KB/s    in 0.09s
#
# 2022-06-28 14:29:26 (2.76 MB/s) - ‘test_image.jpg’ saved [262749/262749]

# %%
from PIL import Image


image = Image.open('test_image.jpg')
image = transforms_test(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image)
    _, preds = torch.max(outputs, 1)
    imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

# %%
# !pip install flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2022.6.15)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
import io
from flask_ngrok import run_with_ngrok
from flask import Flask, jsonify, request


# 이미지를 읽어 결과를 반환하는 함수
def get_prediction(image_bytes):
    image = Image.open(io.BytesIO(image_bytes))
    image = transforms_test(image).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(image)
        _, preds = torch.max(outputs, 1)
        imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    return class_names[preds[0]]


app = Flask(__name__)


@app.route('/', methods=['POST'])
def predict():
    if request.method == 'POST':
        # 이미지 바이트 데이터 받아오기
        file = request.files['file']
        image_bytes = file.read()

        # 분류 결과 확인 및 클라이언트에게 결과 반환
        class_name = get_prediction(image_bytes=image_bytes)
        print("결과:", {'class_name': class_name})
        return jsonify({'class_name': class_name})

# %%
run_with_ngrok(app)
app.run()
